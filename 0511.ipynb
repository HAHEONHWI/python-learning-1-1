# %% [markdown]
# # 리스트 복습

# %%
nums = [10, 20, 30, 40, 50]
for i in nums:
    print(i, end=' ')

print()

for j in range(len(nums)):
    print(nums[j], end=' ')
# Out:
# 10 20 30 40 50
# 10 20 30 40 50

# %%
nums = [3, 5, 7, 9]
n = 0
for i in nums :
    n += i
print('합:',n)

print()
total = 0
for j in range(len(nums)):
    total += nums[j]
print('합:',total)
# Out:
# 합: 24
#
# 합: 24

# %%
nums = [12, 7, 9, 20, 33, 18]
zak = []
for i in nums:
    if i%2 == 0:
        zak.append(i)
for j in zak:
    print(j, end=' ')

print()

zak = []
for j in range(len(nums)):
    if nums[j]%2 == 0:
        zak.append(nums[j])
for k in zak:
    print(k, end=' ')
# Out:
# 12 20 18
# 12 20 18

# %%
nums = [45, 12, 78, 34, 23]
maxi = 0
for i in nums:
    if maxi < i:
        maxi = i
print('최댓값:', maxi)
# Out:
# 최댓값: 78

# %%
scores = [70, 85, 60, 90, 75]
hap =0
for i in range(len(scores)):
    hap += scores[i]
print(f"평균: {hap/len(scores)}")
print("평균 이상 :", end='')
for i in range(len(scores)):
    if scores[i] >= hap/len(scores):
        print(scores[i], end=' ')
# Out:
# 평균: 76.0
# 평균 이상 :85 90

# %%
scores = [70, 85, 60, 90, 75]
hap =0
for i in scores:
    hap += i
print(f"평균: {hap/len(scores)}")
print("평균 이상 :", end='')
for i in scores:
    if i >= hap/len(scores):
        print(i, end=' ')
# Out:
# 평균: 76.0
# 평균 이상 :85 90

# %%
nums = [10, 20, 30, 40, 50, 60]
for i in range(len(nums)):
    if i%2 == 0:
        print(nums[i], end=" ")
# Out:
# 10 30 50

# %%
#7번
nums = [5, 7, 3, 8, 10]
for i in range(len(nums)):
    if nums[i] > nums[i-1] :
        print(nums[i], end=' ')
# Out:
# 7 8 10

# %%
#8번
nums =[10, 15, 13, 20]
for i in range(len(nums)-1):
    print(nums[i+1] - nums[i] , end=' ')
# Out:
# 5 -2 7

# %%
#9번
nums = [1, 2, 3, 4]
for i in range(len(nums)-1, -1, -1):
    print(nums[i], end=' ')

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.__balance = balance
    def deposit(self, amount):
        if amount >0:
            self.__balance += amount
        else:
            print("입금액은 0보다 커야 합니다.")
        
    def get_balance(self):
        return self.__balance
account = BankAccount('철수', 1000)
account.deposit(500)
print(account.get_balance())
# Out:
# 1500

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.__balance = balance

    def get_balance(self):
        return self.__balance
    
    def set_balance(self, balance):
        if balance >= 0:
            self.__balance = balance
        else:
            print("잔액은 0원 이상이어야 합니다")

account = BankAccount('철수', 10000)
print(account.get_balance())

account.set_balance(20000)
print(account.get_balance())

account.__balance = 7000
print(account.get_balance())

print(account.__dict__)
# Out:
# 10000
# 20000
# 20000
# {'owner': '철수', '_BankAccount__balance': 20000, '__balance': 7000}
