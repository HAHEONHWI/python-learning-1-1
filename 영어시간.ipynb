# %%
nums = [100, 200, 300, 400, 500]

nums.remove(400)
nums.remove(500)
print(nums)
# Out:
# [100, 200, 300, 500]

# %%
l = [200, 100, 300]
l.insert(2,10000)
print(l)
# Out:
# [200, 100, 10000, 300]

# %%
year = '2019'
month = '04'
day = '26'
hour = '11'
minute = '34'
second = '27'
print(year, month, day, sep='/', end=' ')
print(hour, minute, second, sep=':')
# Out:
# 2019/04/26 11:34:27

# %%
a = int(input())
for i in range(a):
    print(' ' * (a-i-1), end='')
    print('*' + '*'*i*2)
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************
