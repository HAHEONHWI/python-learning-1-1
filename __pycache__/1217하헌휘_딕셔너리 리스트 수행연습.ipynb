# %%
#1
word = input()

if word == word[::-1]:
    print("팰린드롬입니다.")
else:
    print("팰린드롬이 아닙니다.")
# Out:
# 팰린드롬 아님
# 팰린드롬

# %%
nums = [10, 15, 13, 20]
for i in range(1, len(nums)):
    print(nums[i] - nums[i-1], end=' ')
# Out:
# 5 -2 7
